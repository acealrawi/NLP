# %% [markdown]
# <a href="https://colab.research.google.com/github/acealrawi/NLP/blob/main/Bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
from datasets import load_dataset

dataset = load_dataset("saattrupdan/womens-clothing-ecommerce-reviews")

# %%
#converting it into pandas
dataset.set_format(type="pandas")
df=dataset["train"][:]
df.head()

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon (required for SentimentIntensityAnalyzer)
nltk.download('vader_lexicon')

# Create a SentimentIntensityAnalyzer object
sia = SentimentIntensityAnalyzer()

# %%
# !pip install transformers

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-xlm-roberta-base-sentiment-multilingual")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-xlm-roberta-base-sentiment-multilingual")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="cardiffnlp/twitter-xlm-roberta-base-sentiment-multilingual")

# %%
example =df['review_text'][3]
print(example)

# %%
pip install nltk

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon (required for SentimentIntensityAnalyzer)
nltk.download('vader_lexicon')

# Create a SentimentIntensityAnalyzer object
sia = SentimentIntensityAnalyzer()

# %%
print(example)
sia.polarity_scores(example)

# %%
import numpy as np
from scipy.special import softmax
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg': scores[0],
    'roberta_neu': scores[1],
    'roberta_pos': scores[2]
}
print(scores_dict)

# %%
def polarity_scores_bert(example):
    # Encode the input text
    encoded_text = tokenizer(example, return_tensors='pt')

    # Make predictions using the model
    output = model(**encoded_text)

    # Extract the scores
    scores = output.logits[0].detach().numpy()

    # Apply softmax to get probabilities
    scores = softmax(scores)

    # Create a dictionary of scores
    scores_dict = {
        'roberta_neg': scores[0],
        'roberta_neu': scores[1],
        'roberta_pos': scores[2]
    }

    return scores_dict

# %%
from tqdm.notebook import tqdm

res = {}

for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['review_text']
    myid = row.iloc[0]  # Access the ID value by positional index
    roberta_result = polarity_scores_bert(text)
    result = {**roberta_result }
    res[myid] = result

# %%
roberta_result
# Out:
# {'roberta_neg': 0.038600683,
#  'roberta_neu': 0.047191296,
#  'roberta_pos': 0.914208}

# %%
import pandas as pd
pd.DataFrame(res).T
# Out:
#                                                     roberta_neg  roberta_neu  \
# I loved this shirt until the first time i washe...     0.467321     0.293363
# This sweater was unflattering me, very boxy and...     0.796300     0.107041
# I fell in love with these bottoms at first site...     0.055589     0.075066
# I love the dress!  i purchased this dress to we...     0.009624     0.010289
# I fell in love with this dress when i saw it on...     0.035129     0.133842
# ...                                                         ...          ...
# I really liked these jeans initially, but by th...     0.920677     0.058242
# This top is soo pretty with a cool edge.\r\nit ...     0.007086     0.008502
# I absolutely love this top. i'm always either a...     0.345168     0.302808
# Tts - bought my usual pilcro size. enjoy the fi...     0.030778     0.055940
# Pilcro pants are always a positive purchase. qu...     0.038601     0.047191
#
#                                                     roberta_pos
# I loved this shirt until the first time i washe...     0.239316
# This sweater was unflattering me, very boxy and...     0.096658
# I fell in love with these bottoms at first site...     0.869345
# I love the dress!  i purchased this dress to we...     0.980087
# I fell in love with this dress when i saw it on...     0.831030
# ...                                                         ...
# I really liked these jeans initially, but by th...     0.021081
# This top is soo pretty with a cool edge.\r\nit ...     0.984413
# I absolutely love this top. i'm always either a...     0.352024
# Tts - bought my usual pilcro size. enjoy the fi...     0.913281
# Pilcro pants are always a positive purchase. qu...     0.914208
#
# [20636 rows x 3 columns]

# %%
sentiment_df = pd.DataFrame(res).T

# %%
sentiment_df.head()
# Out:
#                                                     roberta_neg  roberta_neu  \
# I loved this shirt until the first time i washe...     0.467321     0.293363
# This sweater was unflattering me, very boxy and...     0.796300     0.107041
# I fell in love with these bottoms at first site...     0.055589     0.075066
# I love the dress!  i purchased this dress to we...     0.009624     0.010289
# I fell in love with this dress when i saw it on...     0.035129     0.133842
#
#                                                     roberta_pos
# I loved this shirt until the first time i washe...     0.239316
# This sweater was unflattering me, very boxy and...     0.096658
# I fell in love with these bottoms at first site...     0.869345
# I love the dress!  i purchased this dress to we...     0.980087
# I fell in love with this dress when i saw it on...     0.831030

# %%
df.reset_index(drop=True, inplace=True)
sentiment_df.reset_index(drop=True, inplace=True)

# %%
merged_df = pd.concat([df, sentiment_df], axis=1)

# %%
merged_df.head()
# Out:
#                                          review_text  age  rating  \
# 0  I loved this shirt until the first time i wash...   39       1
# 1  This sweater was unflattering me, very boxy an...   44       3
# 2  I fell in love with these bottoms at first sit...   41       5
# 3  I love the dress!  i purchased this dress to w...   34       5
# 4  I fell in love with this dress when i saw it o...   46       5
#
#    positive_feedback_count   division_name department_name class_name  \
# 0                        0         General            Tops      Knits
# 1                        0         General            Tops   Sweaters
# 2                        2         General         Bottoms      Pants
# 3                        0         General         Dresses    Dresses
# 4                        0  General Petite         Dresses    Dresses
#
#    recommended_ind  roberta_neg  roberta_neu  roberta_pos
# 0                0     0.467321     0.293363     0.239316
# 1                0     0.796300     0.107041     0.096658
# 2                1     0.055589     0.075066     0.869345
# 3                1     0.009624     0.010289     0.980087
# 4                1     0.035129     0.133842     0.831030

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
merged_df.columns

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.barplot(data=merged_df[['bert_pos', 'bert_neu', 'bert_neg']], ci=None)
plt.title('Distribution of Sentiment Scores')
plt.ylabel('Frequency')
plt.xlabel('Sentiment')
plt.xticks(ticks=[0, 1, 2], labels=['Positive', 'Neutral', 'Negative'])
plt.show()

# %% [markdown]
# Plot Results

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.boxplot(x='rating', y='bert_pos', data=merged_df, palette="Set3")
plt.title('RoBERTa Positive Sentiment Scores by Rating')
plt.xlabel('Rating')
plt.ylabel('Positive Sentiment Score')

plt.show()

# %%
ax = sns.barplot(data=merged_df, x='rating', y='bert_pos')
ax.set_title('Positive')
plt.show()

# %%
ax = sns.barplot(data=merged_df, x='rating', y='bert_neg')
ax.set_title('Negative')
plt.show()
